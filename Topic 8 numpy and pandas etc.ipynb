# %%
pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 7.5 MB/s eta 0:00:0000:0100:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.5/505.5 kB 9.0 MB/s eta 0:00:00ta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 5.6 MB/s eta 0:00:0000:01
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
data = pd.read_csv('data.csv')
data
# Out:
#                 Submission Date Who was your coaching call with?  \
# 0     2021 December 15, 11:56AM               Michael Bondarenko
# 1     2021 December 16, 10:39AM                   Joshua Fimmano
# 2      2021 December 16, 2:31PM                   Joshua Fimmano
# 3      2021 December 18, 1:38PM                   Joshua Fimmano
# 4      2021 December 18, 2:08PM                   Joshua Fimmano
# ...                         ...                              ...
# 2112    2024 January 23, 8:51AM                  Shahin Ghorbani
# 2113    2024 January 22, 9:19PM                  Shahin Ghorbani
# 2114   2024 January 22, 11:54PM                  Shahin Ghorbani
# 2115    2024 January 23, 3:26AM                  Shahin Ghorbani
# 2116    2024 January 23, 4:23AM                  Shahin Ghorbani
#
#      What did you work on in the coaching call?  \
# 0                             Ad Account Review
# 1                               Ad Angle Review
# ...

# %%
data.describe()
# Out:
#        Was the purpose of the call fulfilled? (Did the coach successfully help you with what you wanted?)  \
# count                                        2117.000000
# mean                                            4.897496
# std                                             0.475663
# min                                             1.000000
# 25%                                             5.000000
# 50%                                             5.000000
# 75%                                             5.000000
# max                                             5.000000
#
#        Were all of your questions answered and clearly explained?  \
# count                                        2117.000000
# mean                                            4.900803
# std                                             0.457643
# min                                             1.000000
# 25%                                             5.000000
# ...

# %%
data.plot('How was the coaches attitude on the call?',kind='bar')
# Out:
# <Axes: xlabel='How was the coaches attitude on the call?'>

# %%
data.columns
# Out:
# Index(['Submission Date', 'Who was your coaching call with?',
#        'What did you work on in the coaching call?',
#        'Was the purpose of the call fulfilled? (Did the coach successfully help you with what you wanted?)',
#        'Were all of your questions answered and clearly explained?',
#        'How was the coaches attitude on the call?',
#        'Rate your overall experience in the call',
#        'Do you have any ideas / recommendations that would help improve your experience?',
#        'Are there any improvements you'd like to see from the coaches?',
#        'utm_source', 'utm_campaign', 'utm_medium', 'utm_term', 'Submission ID',
#        'Week-Year', 'Avg', 'Streak'],
#       dtype='object')

# %%
data.loc[data['Avg']<2,].to_csv('new_data.csv')

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(1,100,0.01)
y = np.sin(x)
plt.plot(x,y)
